# %%
import json
import urllib.request
import urllib.parse
import pandas as pd
import os
import glob

# %%
def make_url(community_area: str, neighbourhood_cluster: str, neighbourhood: str):
    if community_area == neighbourhood_cluster:
        return f"https://legacy.winnipeg.ca/Census/2016/Community Areas/{community_area} Neighbourhood Cluster/{neighbourhood_cluster} Neighbourhoods/{neighbourhood}/{neighbourhood}.xlsx".replace(" ", "%20")
    else:
        return f"https://legacy.winnipeg.ca/Census/2016/Community%20Areas/{community_area} Neighbourhood Cluster/Neighbourhoods/{neighbourhood_cluster}/{neighbourhood_cluster} Neighbourhoods/{neighbourhood}/{neighbourhood}.xlsx".replace(" ", "%20")

# %%
neighbourhoods = list()
neighbourhoods.append(["Assiniboine South", "Assiniboine South", "Betsworth", "Edgeland", "Elmhurst", "Eric Coy", "Marlton", "Old Tuxedo", "Ridgedale", "Ridgewood South", "River West Park", "Roblin Park", "South Tuxedo", "Southboine", "Tuxedo", "Tuxedo Industrial", "Varsity View", "Vialoux", "Westdale", "Wilkes South"])
neighbourhoods.append(["Downtown", "Downtown East", "Armstrong Point", "Broadway-Assiniboine", "Centennial", "Central Park", "China Town", "Civic Centre", "Colony", "Exchange District", "Logan-C.P.R.", "Portage-Ellice", "South Portage", "Spence", "West Alexander", "West Broadway"])
neighbourhoods.append(["Downtown", "Downtown West", "Daniel McIntyre", "Minto", "Polo Park", "Sargent Park", "St. Matthews", "West Wolseley", "Wolseley"])
neighbourhoods.append(["Fort Garry", "Fort Garry North", "Beaumont", "Brockville", "Crescent Park", "Linden Ridge", "Linden Woods", "Maybank", "Pembina Strip", "Point Road", "Whyte Ridge", "Wildwood"])
neighbourhoods.append(["Fort Garry", "Fort Garry South", "Agassiz", "Bridgwater Centre", "Bridgwater Forest", "Bridgwater Lakes", "Bridgwater Trails", "Cloutier Drive", "Fairfield Park", "Fort Richmond", "Montcalm", "Parc La Salle", "Richmond Lakes", "Richmond West", "South Pointe", "St. Norbert", "Waverley Heights"])
neighbourhoods.append(["Inkster", "Inkster East", "Brooklands", "Burrows-Keewatin", "Shaughnessy Park", "Weston"])
neighbourhoods.append(["Inkster", "Inkster West", "Inkster Gardens", "North Inkster Industrial", "Tyndall Park"])
neighbourhoods.append(["Point Douglas", "Point Douglas North", "Burrows Central", "Inkster-Faraday", "Luxton", "Mynarski", "Robertson", "St. Johns", "St. Johns Park"])
neighbourhoods.append(["Point Douglas", "Point Douglas South", "Dufferin", "Lord Selkirk Park", "North Point Douglas", "South Point Douglas", "William Whyte"])
neighbourhoods.append(["River East", "River East East", "Eaglemere", "Grassie", "Kil-cona Park", "Munroe East", "Springfield North", "Springfield South", "Valley Gardens"])
neighbourhoods.append(["River East", "River East South", "Chalmers", "East Elmwood", "Glenelm", "Talbot-Grey"])
neighbourhoods.append(["River East", "River East West", "Kildonan Drive", "Munroe West", "River East", "Rossmere-A", "Rossmere-B", "Valhalla"])
neighbourhoods.append(["River Heights", "River Heights East", "Lord Roberts", "McMillan", "River-Osborne", "Riverview", "Roslyn"])
neighbourhoods.append(["River Heights", "River Heights West", "Central River Heights", "Crescentwood", "Earl Grey", "Ebby-Wentworth", "Grant Park", "J.B. Mitchell", "Mathers", "North River Heights", "Rockwood", "Sir John Franklin", "South River Heights", "Wellington Crescent"])
neighbourhoods.append(["Seven Oaks", "Seven Oaks East", "Garden City", "Jefferson", "Leila North", "Leila-McPhillips Triangle", "Margaret Park", "Riverbend", "Rivergrove", "Seven Oaks", "Templeton-Sinclair"])
neighbourhoods.append(["Seven Oaks", "Seven Oaks West", "Amber Trails", "Mandalay West", "Rosser-Old Kildonan", "The Maples"])
neighbourhoods.append(["St. Boniface", "St. Boniface East", "Archwood", "Dufresne", "Holden", "Island Lakes", "Maginot", "Niakwa Park", "Niakwa Place", "Royalwood", "Sage Creek", "Southdale", "Southland Park", "St. Boniface Industrial Park", "Stock Yards", "Windsor Park"])
neighbourhoods.append(["St. Boniface", "St. Boniface West", "Central St. Boniface", "North St. Boniface", "Norwood East", "Norwood West"])
neighbourhoods.append(["St. James - Assiniboia", "St. James - Assiniboia East", "Airport", "Birchwood", "Booth", "Bruce Park", "Deer Lodge", "Jameswood", "Kensington", "King Edward", "Silver Heights", "Woodhaven"])
neighbourhoods.append(["St. James - Assiniboia", "St. James - Assiniboia West", "Assiniboia Downs", "Buchanan", "Crestview", "Glendale", "Heritage Park", "Kirkfield", "Sturgeon Creek", "Westwood"])
neighbourhoods.append(["St. Vital", "St. Vital North", "Alpine Place", "Elm Park", "Glenwood", "Kingston Crescent", "Lavalee", "Norberry", "Pulberry", "St. George", "Varennes", "Victoria Crescent", "Worthington"])
neighbourhoods.append(["St. Vital", "St. Vital South", "Dakota Crossing", "Meadowood", "Minnetonka", "Normand Park", "River Park South", "St. Vital Perimeter South", "Vista"])
neighbourhoods.append(["Transcona", "Transcona", "Canterbury Park","Kern Park", "Kildare-Redonda", "Meadows", "Melrose", "Mission Gardens", "Peguis", "Radisson", "Transcona South", "Victoria West"])

# nodata:
# Assiniboine South, West Perimeter South
# Transcona, Griffin
# Downtown East, The Forks, Portage and Main
# Fort Garry North, Buffalo, Parker, West Fort Garry Industrial
# Fort Garry South, La Barriere, Perrault, Trappistes, Turnbull Drive, University, Waverly West B
# Inkster West, Oak Point Highway
# Inkster East, Pacific Industrial, Weston Shops, Inkster Industrial Park
# Point Douglas South, Dufferin Industrial
# Seven Oaks East, West Kildonan Industrial
# St. Vital South, Maple Grove Park
# Transcona, Regent, Transcona Yards
# St. James - Assiniboia West, Saskatchewan North
# River East South, Tyne-Tees
# St. James - Assiniboia East, Murray Industrial Park, Omand's Creek Industrial, St. James Industrial
# River East East, Kildonan Crossing, McLeod Industrial, North Transcona Yards
# St. Boniface East, Dugald, The Mint, Mission Industrial, Tissot, Fraipont, Symington Yards



urls = list()
for i in neighbourhoods:
    for j in range(2, len(i)):
        urls.append(make_url(i[0], i[1], i[j]))

urls
# Out:
# ['https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Assiniboine%20South%20Neighbourhood%20Cluster/Assiniboine%20South%20Neighbourhoods/
xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/St.%20Vital%20Neighbourhood%20Cluster/Neighbourhoods/St.%20Vital%20South/St.%20Vital%20South%20Neighbourhoods/Meadowood/Meadowood.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/St.%20Vital%20Neighbourhood%20Cluster/Neighbourhoods/St.%20Vital%20South/St.%20Vital%20South%20Neighbourhoods/Minnetonka/Minnetonka.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/St.%20Vital%20Neighbourhood%20Cluster/Neighbourhoods/St.%20Vital%20South/St.%20Vital%20South%20Neighbourhoods/Normand%20Park/Normand%20Park.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/St.%20Vital%20Neighbourhood%20Cluster/Neighbourhoods/St.%20Vital%20South/St.%20Vital%20South%20Neighbourhoods/River%20Park%20South/River%20Park%20South.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/St.%20Vital%20Neighbourhood%20Cluster/Neighbourhoods/St.%20Vital%20South/St.%20Vital%20South%20Neighbourhoods/St.%20Vital%20Perimeter%20South/St.%20Vital%20Perimeter%20South.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/St.%20Vital%20Neighbourhood%20Cluster/Neighbourhoods/St.%20Vital%20South/St.%20Vital%20South%20Neighbourhoods/Vista/Vista.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Canterbury%20Park/Canterbury%20Park.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Kern%20Park/Kern%20Park.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Kildare-Redonda/Kildare-Redonda.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Meadows/Meadows.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Melrose/Melrose.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Mission%20Gardens/Mission%20Gardens.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Peguis/Peguis.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Radisson/Radisson.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Transcona%20South/Transcona%20South.xlsx',
# 'https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Transcona%20Neighbourhood%20Cluster/Transcona%20Neighbourhoods/Victoria%20West/Victoria%20West.xlsx'
#
# $urls += "https://legacy.winnipeg.ca/Census/2016/Community%20Areas/Downtown%20Neighbourhood%20Cluster/Neighbourhoods/Downtown%20East/Downtown%20East%20Neighbourhoods/Logan-C.P.R/Logan-C.P.R..xlsx"
#
# foreach ($url in $urls)
# {
#     $out = $url.Split('/')[-1].Replace('%20', ' ')
#
#     if (Test-Path $out) { continue }
#
#     # download files from url
#     $file = Invoke-WebRequest -Uri $url -OutFile $out
#
#     # if file is smaller than 4kb, write url to file log.txt
#     if ((Get-Item $out).Length -lt 4096)
#     {
#         Add-Content log.txt $url+"\n"
#         Remove-Item $out
#     }
# }
# Out:
# Couldn't find program: 'false'

# %%
census_2016 = []
for xlsx in glob.glob(os.path.join("assets/census/", "*.xlsx")):
    xlsx = pd.read_excel(xlsx)
    neighbourhood_name = xlsx["Unnamed: 0"][16]
    population_density = xlsx["Unnamed: 2"][72]
    past_population = xlsx["Unnamed: 1"][53:63].tolist()
    year_opened = 1971
    for i in range(len(past_population)):
        if past_population[i] == 0:
            year_opened = 2016-(i-1)*5
            break
        else:
            continue

    visible_minorities = xlsx["Unnamed: 1"][201:213].astype(int).nlargest(3)
    commuting_method_male = [xlsx["Unnamed: 1"][475], xlsx["Unnamed: 1"][476:481].astype(int).sum()]
    commuting_method_female = [xlsx["Unnamed: 2"][475], xlsx["Unnamed: 2"][476:481].astype(int).sum()]

    avg_med_income = [0, 0]
    try:
        avg_med_income = xlsx["Unnamed: 1"][613:615].astype(int).tolist()
    except:
        pass
    
    census_2016.append({"Boundary Type": "Neighbourhood", 
                        "Boundary Name": neighbourhood_name, 
                        "Population 2016": xlsx["Unnamed: 1"][53],
                        "Population Density 2016": population_density, 
                        "Year opened": year_opened,
                        "Aboriginal": xlsx["Unnamed: 1"][182],
                        "Aboriginal Percent": xlsx["Unnamed: 3"][182],
                        "Visible Minorities Names": [s.strip() for s in xlsx["Unnamed: 0"].iloc[visible_minorities.index.tolist()].tolist()],
                        "Visible Minorities Numbers": visible_minorities.values.tolist(),
                        "Visible Minorities Percent": xlsx["Unnamed: 2"].iloc[visible_minorities.index.tolist()].tolist(),
                        "Visible Minorities Total Number": xlsx["Unnamed: 1"][213],
                        "Visible Minorities Total Percent": xlsx["Unnamed: 1"][213] / xlsx["Unnamed: 1"][53],
                        "Citizenship Numbers": xlsx["Unnamed: 1"][221:223].tolist(),
                        "Citizenship Percent": xlsx["Unnamed: 2"][221:223].tolist(),
                        "Education Numbers": xlsx["Unnamed: 1"][386:389].tolist(),
                        "Education Percent": xlsx["Unnamed: 2"][386:389].tolist(),
                        "Unemployment Rate": xlsx["Unnamed: 3"][409],
                        "Period of Construction": xlsx["Unnamed: 1"][702:709].astype(int).nlargest(3).tolist(),
                        "Period of Construction Percent": xlsx["Unnamed: 2"].iloc[xlsx["Unnamed: 1"][702:709].astype(int).nlargest(3).index.tolist()].tolist(),
                        "Period of Construction Name": [s.strip() for s in xlsx["Unnamed: 0"].iloc[xlsx["Unnamed: 1"][702:709].astype(int).nlargest(3).index.tolist()].tolist()],
                        "Household Type": [xlsx["Unnamed: 1"][676:679].astype(int).sum(), xlsx["Unnamed: 1"][679:682].astype(int).sum(), xlsx["Unnamed: 1"][682:684].astype(int).sum()],
                        "Own vs Rent": xlsx["Unnamed: 1"][690:692].astype(int).tolist(),
                        "Own vs Rent Percent": xlsx["Unnamed: 2"][690:692].tolist(),
                        "Bad Dwelling": xlsx["Unnamed: 1"][697],
                        "Bad Dwelling Percent": xlsx["Unnamed: 2"][697],
                        "Average and Median Household Income": avg_med_income,
                        "Commuting Method": [commuting_method_male[0] + commuting_method_female[0], commuting_method_male[1] + commuting_method_female[1]],
                        "Commuting Method Percent": [xlsx["Unnamed: 3"][475], xlsx["Unnamed: 3"][476:481].astype(float).sum()]
                        })

census_2016 = pd.DataFrame(census_2016)
census_2016.to_csv("assets/census_2016_new.csv", index=False)

# %%
xlsx = pd.read_excel("assets\census\Alpine Place.xlsx")

# %%
period_of_construction = xlsx["Unnamed: 1"][702:709].astype(int).nlargest(3)
period_of_construction_name = [s.strip() for s in xlsx["Unnamed: 0"].iloc[period_of_construction.index.tolist()].tolist()]
period_of_construction_percent = xlsx["Unnamed: 2"].iloc[period_of_construction.index.tolist()].tolist()

# %%
household_type = [xlsx["Unnamed: 1"][676:679].astype(int).sum(), xlsx["Unnamed: 1"][679:682].astype(int).sum(), xlsx["Unnamed: 1"][682:684].astype(int).sum()]
own_rent = xlsx["Unnamed: 1"][690:692].astype(int).tolist()
own_rent_percent = xlsx["Unnamed: 2"][690:692].tolist()
bad_dwelling = xlsx["Unnamed: 1"][697]
bad_dwelling_percent = xlsx["Unnamed: 2"][697]

# %%
avg_median_household_income = xlsx["Unnamed: 1"][613:615].astype(int).tolist()

# %%
commuting_method_male = [xlsx["Unnamed: 1"][475], xlsx["Unnamed: 1"][476:481].astype(int).sum()]
commuting_method_female = [xlsx["Unnamed: 2"][475], xlsx["Unnamed: 2"][476:481].astype(int).sum()]
commuting_method = [commuting_method_male[0] + commuting_method_female[0], commuting_method_male[1] + commuting_method_female[1]]
commuting_method_percent = [xlsx["Unnamed: 3"][475], xlsx["Unnamed: 3"][476:481].astype(float).sum()]
